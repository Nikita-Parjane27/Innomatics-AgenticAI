# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita-Parjane27/Innomatics-AgenticAI/blob/main/LogicBuilding_Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Problem 1: Unique Words in a Sentence

sentence = input("Enter sentence: ")

words = sentence.split()
unique_words = set(words)

print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence: Programming in Python
# Unique words count: 3
# Unique words: {'Python', 'Programming', 'in'}

# %%
## Problem 2: Highest Salary from Employee Data

employees = {
    "Raj": 75000,
    "Ankita": 68000,
    "Kirshvi": 72000
}

highest_salary = 0
highest_employee = ""

for name, salary in employees.items():
    if salary > highest_salary:
        highest_salary = salary
        highest_employee = name

print("Highest Salary:", highest_employee, "-", highest_salary)
# Out:
# Highest Salary: Raj - 75000

# %%
## Problem 3: Find Maximum and Minimum Values

numbers = [45, 22, 89, 10, 66]

max_value = numbers[0]
min_value = numbers[0]

for num in numbers:
    if num > max_value:
        max_value = num
    if num < min_value:
        min_value = num

print("List:", numbers)
print("Max:", max_value)
print("Min:", min_value)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
## Problem 4: Count Products Above a Price Threshold

prices = [450, 1200, 899, 1500, 300]

count = 0

for price in prices:
    if price > 1000:
        count += 1

print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %%
## Problem 5: Calculate Attendance Percentage

attendance = ["P", "P", "A", "P", "P"]

present_count = attendance.count("P")
total_days = len(attendance)

percentage = (present_count / total_days) * 100

print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %%
## Problem 6: Remove Duplicate Phone Numbers

phone_numbers = [9876543210, 9123456789, 9876543210]

unique_numbers = set(phone_numbers)

print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
## Problem 7: Count Character Frequency


text = "Programming"

frequency = {}

for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print(frequency)
# Out:
# {'P': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
## Problem 8: Convert List to Tuple

numbers = [10, 20, 30]

tuple_data = tuple(numbers)

print("Tuple:", tuple_data)
# Out:
# Tuple: (10, 20, 30)

# %%
## Problem 9: Check if a Key Exists in a Dictionary

employees = {
    "Nikita": 75000,
    "Ankita": 68000
}

key = "Nikita"

if key in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %%
## Problem 10: Calculate Average Marks

marks = [70, 80, 65, 75]

total = sum(marks)
average = total / len(marks)

print("Average Marks:", average)
# Out:
# Average Marks: 72.5
