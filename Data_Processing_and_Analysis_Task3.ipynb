# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita-Parjane27/Innomatics-AgenticAI/blob/main/Data_Processing_and_Analysis_Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Employee Performance Bonus Eligibility

# %%
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

# 1: Find highest score
highest_score = max(employees.values())

# 2: Find all employees with highest score
top_performers = [name for name, score in employees.items() if score == highest_score]

# 3: Display result
print(f"Top Performers Eligible for Bonus: {', '.join(top_performers)} (Score: {highest_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# Problem 2: Search Query Keyword Analysis

# %%
import string

query = "Buy mobile phone buy phone online"

#1: Convert to lowercase
query = query.lower()

#2: Remove punctuation
query = query.translate(str.maketrans('', '', string.punctuation))

#3: Split into words
words = query.split()

#4: Count frequency
word_count = {}
for word in words:
    word_count[word] = word_count.get(word, 0) + 1

#5: Filter words appearing more than once
repeated_words = {word: count for word, count in word_count.items() if count > 1}
print(repeated_words)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# Problem 3: Sensor Data Validation

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]

# Store valid readings
valid_readings = [(index, value)
                  for index, value in enumerate(sensor_readings)
                  if value % 2 == 0]

print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# Problem 4: Email Domain Usage Analysis

# %%
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

#1: Extract domains
domain_count = {}
for email in emails:
    domain = email.split("@")[1]
    domain_count[domain] = domain_count.get(domain, 0) + 1

#2: Calculate percentage
total_emails = len(emails)

print("Email Domain Usage:")
for domain, count in domain_count.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {percentage:.0f}%")
# Out:
# Email Domain Usage:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# Problem 5: Sales Spike Detection

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

#1: Calculate average
average_sales = sum(sales) / len(sales)

#2: Detect spikes (more than 30% above average)
threshold = average_sales * 1.3

print("Sales Spikes Detected:")
for day, value in enumerate(sales, start=1):
    if value > threshold:
        print(f"Day {day}: {value}")
# Out:
# Sales Spikes Detected:
# Day 6: 3000

# %% [markdown]
# Problem 6: Duplicate User ID Detection

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

#Occurrences
id_count = {}
for user in user_ids:
    id_count[user] = id_count.get(user, 0) + 1

# Display duplicates
print("Duplicate User IDs:")
for user, count in id_count.items():
    if count > 1:
        print(f"{user} → {count} times")
# Out:
# Duplicate User IDs:
# user1 → 3 times
# user3 → 2 times
